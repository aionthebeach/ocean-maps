# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Ocean Research

# %%
All_Animals_Oceanreach = pd.read_csv('Oceanreach/All_Animal_Data.csv')
All_Animals_Oceanreach.head(10)
# Out:
#    active             datetime  id  latitude  longitude  \
# 0       1  2012-03-16 18:31:39   1   -34.142     22.200
# 1       1  2012-03-16 18:48:58   2   -34.115     22.201
# 2       1  2012-03-16 20:15:40   3   -34.138     22.200
# 3       1  2012-03-16 23:09:05   4   -34.192     22.228
# 4       1   2012-03-17 0:36:43   5   -34.204     22.239
# 5       1   2012-03-17 0:52:50   6   -34.210     22.209
# 6       1   2012-03-17 1:16:51   7   -34.218     22.208
# 7       1   2012-03-17 2:36:14   8   -34.236     22.204
# 8       1   2012-03-17 4:32:38   9   -34.224     22.187
# 9       1   2012-03-17 4:33:52  10   -34.246     22.208
#
#                        tz_datetime                           animal_type  \
# 0   16 March 2012 6:31:39 PM +0900  White Shark (Carcharodon carcharias)
# 1   16 March 2012 6:48:58 PM +0900  White Shark (Carcharodon carcharias)
# 2   16 March 2012 8:15:40 PM +0900  White Shark (Carcharodon carcharias)
# 3  16 March 2012 11:09:05 PM +0900  White Shark (Carcharodon carcharias)
# 4  17 March 2012 12:36:43 AM +0900  White Shark (Carcharodon carcharias)
# 5  17 March 2012 12:52:50 AM +0900  White Shark (Carcharodon carcharias)
# 6   17 March 2012 1:16:51 AM +0900  White Shark (Carcharodon carcharias)
# 7   17 March 2012 2:36:14 AM +0900  White Shark (Carcharodon carcharias)
# 8   17 March 2012 4:32:38 AM +0900  White Shark (Carcharodon carcharias)
# 9   17 March 2012 4:33:52 AM +0900  White Shark (Carcharodon carcharias)
#
#    animal_id  epoch_time
# 0          9  1331922699
# 1          9  1331923738
# 2          9  1331928940
# 3          9  1331939345
# 4          9  1331944603
# 5          9  1331945570
# 6          9  1331947011
# 7          9  1331951774
# 8          9  1331958758
# 9          9  1331958832

# %%
print("Latitude Min:", All_Animals_Oceanreach.latitude.min())
print("Latitude Max:", All_Animals_Oceanreach.latitude.max())

print("Longitude Min:", All_Animals_Oceanreach.longitude.min())
print("Longitude Max:", All_Animals_Oceanreach.longitude.max())
# Out:
# Latitude Min: -45.62415
# Latitude Max: 53.65843
# Longitude Min: -177.57416669999998
# Longitude Max: 179.1386111

# %%
Complete_Oceanreach = pd.read_csv('Oceanreach/complete_df.csv').dropna(how='all')
Complete_Oceanreach.head(10)
# Out:
#    Unnamed: 0  shark_id  prg_no       lat      long  loc_quality  \
# 0           7    176750    6328  42.21174 -69.76559            2
# 1          19    176750    6328  42.22635 -69.29816            3
# 2          21    176750    6328  42.23238 -69.26292            0
# 3          37    176750    6328  42.17643 -68.26119            0
# 4          46    176750    6328  42.09855 -68.03666            0
# 5          51    176750    6328  42.13153 -68.00633            0
# 6          58    176750    6328  42.08878 -67.94891            2
# 7          70    176750    6328  42.37687 -67.96824            2
# 8          92    176750    6328  42.34061 -68.13517            1
# 9         105    176750    6328  42.34930 -68.34996            2
#
#               loc_date loc_type  alt  pass  ... semi_major_axis  \
# 0   2018-08-03 0:34:00    Argos    0   232  ...            1113
# 1   2018-08-05 1:35:00    Argos    0   364  ...             608
# 2   2018-08-05 1:35:00    Argos    0   241  ...           40196
# 3  2018-08-08 13:23:00    Argos    0   329  ...           75151
# 4  2018-08-09 14:54:00    Argos    0   159  ...           98147
# 5  2018-08-09 20:27:00    Argos    0   324  ...           40784
# 6   2018-08-10 0:12:00    Argos    0   173  ...            2836
# 7  2018-08-11 15:52:00    Argos    0   506  ...             593
# 8  2018-08-13 22:51:00    Argos    0   299  ...            5250
# 9  2018-08-14 13:10:00    Argos    0   333  ...             954
#
#    semi_minor_axis ellipse_orientation  gdop       depth  \
# 0              111                 147   941 -230.133287
# 1               79                  75   250 -210.668800
# 2               89                  80  1361 -203.973541
# 3              234                 105  1213 -194.135294
# 4              275                  93  3037 -219.582365
# 5               67                  86  2202 -230.846683
# 6               78                  96  1296 -204.266227
# 7              263                  84   322 -171.737983
# 8               71                  73   522 -190.455827
# 9              153                  40   594 -207.999899
#
#    depthChangeDownstream  depthChangeUpstream     bearing  \
# 0              40.972394             2.416062    0.000000
# 1              13.669697           -12.705825  103.202092
# 2               4.200017           -26.632427   95.444627
# 3               6.043765             4.494556  108.364567
# 4              -7.287249            14.605635  124.597846
# 5               5.151836             9.263103   58.119684
# 6               6.915460            34.275356  142.201625
# 7             -15.673507            13.783780   11.700808
# 8              -4.861464           -20.543565  -86.652638
# 9              15.253002           -17.680116  -72.138215
#
#                     timeStep  distanceStep
# 0  0 days 00:00:00.000000000      0.000000
# 1  2 days 01:01:00.000000000     52.059668
# 2  0 days 00:00:00.000000000      3.979929
# 3  3 days 11:48:00.000000000    111.686277
# 4  1 days 01:31:00.000000000     26.455522
# 5  0 days 05:33:00.000000000      4.987814
# 6  0 days 03:45:00.000000000      7.968995
# 7  1 days 15:40:00.000000000     32.142257
# 8  2 days 06:59:00.000000000     19.015970
# 9  0 days 14:19:00.000000000     23.929961
#
# [10 rows x 35 columns]

# %%
print("Latitude Min:", Complete_Oceanreach.lat.min())
print("Latitude Max:", Complete_Oceanreach.lat.max())

print("Longitude Min:", Complete_Oceanreach.long.min())
print("Longitude Max:", Complete_Oceanreach.long.max())
# Out:
# Latitude Min: 37.86031
# Latitude Max: 42.91665
# Longitude Min: -69.76559
# Longitude Max: -58.54532

# %% [markdown]
# ### Beneath the Waves

# %%
AG_GFW_Meta_BTW = pd.read_csv('Beneath_The_Waves/AG_GFW_Meta.csv').dropna(how='all')
AG_GFW_Meta_BTW.head(10)
# Out:
#    SpeciesCode  SPOT PTT TagType  TagDay  TagMonth  TagYear TagTime  \
# 1          BSH  106744.0    SPOT    27.0       8.0   2016.0     NaN
# 3          BSH  106745.0    SPOT    28.0       8.0   2016.0   13:33
# 5          BSH  106746.0    SPOT    28.0       8.0   2016.0   12:33
# 7          BSH  106747.0    SPOT    18.0      10.0   2016.0     NaN
# 9          BSH  106748.0    SPOT    27.0       8.0   2016.0   12:33
# 11         BSH  141261.0    SPOT    13.0      10.0   2015.0   14:45
# 13         BSH  141262.0    SPOT    28.0       8.0   2016.0   15:27
# 15         BSH  141263.0    SPOT    25.0       8.0   2016.0   13:21
# 17         BSH  141264.0    SPOT    21.0      10.0   2015.0   16:16
# 19         BSH  141265.0    SPOT    27.0       8.0   2016.0   12:00
#
#        TagLat    TagLong  TL_cm Sex Maturity OcearchName          Species  \
# 1   41.404333 -69.298667    277   M    adult         Don  Prionace glauca
# 3   41.520500 -69.427500    270   M    adult       Vader  Prionace glauca
# 5   41.536667 -69.418833    262   M    adult       Ciona  Prionace glauca
# 7   41.466667 -69.333333    244   M    adult     Cubswin  Prionace glauca
# 9   41.094567 -69.380333    245   M    adult     Mahkato  Prionace glauca
# 11  41.321267 -69.275833    254   M    adult      Johnny  Prionace glauca
# 13  41.535333 -69.419500  220.5   M    adult       Warne  Prionace glauca
# 15  41.487000 -69.326000    248   M    adult     Machaca  Prionace glauca
# 17  41.587333 -69.446667    254   M    adult      Roland  Prionace glauca
# 19  41.094567 -69.380333    241   M    adult    Sawtooth  Prionace glauca
#
#     Unnamed: 14 Unnamed: 15 Unnamed: 16
# 1           NaN         NaN         NaN
# 3           NaN         NaN         NaN
# 5           NaN         NaN         NaN
# 7           NaN         NaN         NaN
# 9           NaN         NaN         NaN
# 11          NaN         NaN         NaN
# 13          NaN         NaN         NaN
# 15          NaN         NaN         NaN
# 17          NaN         NaN         NaN
# 19          NaN         NaN         NaN

# %%
print("Latitude Min:", AG_GFW_Meta_BTW.TagLat.min())
print("Latitude Max:", AG_GFW_Meta_BTW.TagLat.max())

print("Longitude Min:", AG_GFW_Meta_BTW.TagLong.min())
print("Longitude Max:", AG_GFW_Meta_BTW.TagLong.max())
# Out:
# Latitude Min: 41.09456667
# Latitude Max: 41.80286667
# Longitude Min: -69.83333333
# Longitude Max: -69.27583333

# %%
Beneath_The_Waves_Sensor = pd.read_csv('Beneath_The_Waves/Beneath_The_Waves.csv').dropna(how='all')
Beneath_The_Waves_Sensor.head(10)
# Out:
#    DeployID  Shark ID  Prg No.  Latitude  Longitude Loc. quality  \
# 0       NaN    176750     6328       NaN        NaN          NaN
# 1       NaN    176750     6328       NaN        NaN          NaN
# 2       NaN    176750     6328       NaN        NaN          NaN
# 3       NaN    176750     6328       NaN        NaN          NaN
# 4       NaN    176750     6328  52.09686  -18.56774            A
# 5       NaN    176750     6328  52.09686  -18.56774            A
# 6       NaN    176750     6328  52.09686  -18.56774            A
# 7       NaN    176750     6328  42.21174  -69.76559            2
# 8       NaN    176750     6328  42.21174  -69.76559            2
# 9       NaN    176750     6328  42.21174  -69.76559            2
#
#       Loc. date Loc. type  Altitude  Pass  ... SENSOR #23  SENSOR #24  \
# 0           NaN       NaN       NaN     0  ...        NaN         NaN
# 1           NaN       NaN       NaN     0  ...        NaN         NaN
# 2           NaN       NaN       NaN     0  ...        NaN         NaN
# 3           NaN       NaN       NaN     0  ...        NaN         NaN
# 4  8-2-18 23:40     Argos       0.0   407  ...        NaN         NaN
# 5  8-2-18 23:40     Argos       0.0   407  ...        NaN         NaN
# 6  8-2-18 23:40     Argos       0.0   407  ...        NaN         NaN
# 7   8-3-18 0:34     Argos       0.0   232  ...        NaN         NaN
# 8   8-3-18 0:34     Argos       0.0   232  ...        NaN         NaN
# 9   8-3-18 0:34     Argos       0.0   232  ...        NaN         NaN
#
#    SENSOR #25 SENSOR #26  SENSOR #27  SENSOR #28  SENSOR #29  SENSOR #30  \
# 0         NaN        NaN         NaN         NaN         NaN         NaN
# 1         NaN        NaN         NaN         NaN         NaN         NaN
# 2         NaN        NaN         NaN         NaN         NaN         NaN
# 3         NaN        NaN         NaN         NaN         NaN         NaN
# 4         NaN        NaN         NaN         NaN         NaN         NaN
# 5         NaN        NaN         NaN         NaN         NaN         NaN
# 6         NaN        NaN         NaN         NaN         NaN         NaN
# 7         NaN        NaN         NaN         NaN         NaN         NaN
# 8         NaN        NaN         NaN         NaN         NaN         NaN
# 9         NaN        NaN         NaN         NaN         NaN         NaN
#
#    SENSOR #31  SENSOR #32
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
# 5         NaN         NaN
# 6         NaN         NaN
# 7         NaN         NaN
# 8         NaN         NaN
# 9         NaN         NaN
#
# [10 rows x 62 columns]

# %%
print("Latitude Min:", Beneath_The_Waves_Sensor.Latitude.min())
print("Latitude Max:", Beneath_The_Waves_Sensor.Latitude.max())

print("Longitude Min:", Beneath_The_Waves_Sensor.Longitude.min())
print("Longitude Max:", Beneath_The_Waves_Sensor.Longitude.max())
# Out:
# Latitude Min: 37.86031
# Latitude Max: 52.09686
# Longitude Min: -69.76631
# Longitude Max: -18.56774

# %%
Gallagher_Tracks_BTW = pd.read_csv('Beneath_The_Waves/Gallagher_BTW_Tracks.csv')
Gallagher_Tracks_BTW.head(10)
# Out:
#       ptt             dt        lat        lon class  Unnamed: 5
# 0  106744   8-27-16 0:00  41.404333 -69.298667     3         NaN
# 1  106744  8-27-16 23:29  41.416000 -69.157000     0         NaN
# 2  106744  8-27-16 23:29  41.415600 -69.157400     0         NaN
# 3  106744   8-28-16 9:26  41.326800 -69.132600     1         NaN
# 4  106744   8-28-16 9:29  41.327000 -69.133000     1         NaN
# 5  106744  8-28-16 11:06  41.310100 -69.143200     0         NaN
# 6  106744  8-28-16 11:08  41.310000 -69.143000     0         NaN
# 7  106744  8-28-16 20:49  41.419400 -69.303200     A         NaN
# 8  106744  8-28-16 20:50  41.419000 -69.303000     A         NaN
# 9  106744  8-28-16 22:07  41.407000 -69.049000     A         NaN

# %%
print("Latitude Min:", Gallagher_Tracks_BTW.lat.min())
print("Latitude Max:", Gallagher_Tracks_BTW.lat.max())

print("Longitude Min:", Gallagher_Tracks_BTW.lon.min())
print("Longitude Max:", Gallagher_Tracks_BTW.lon.max())
# Out:
# Latitude Min: 10.435
# Latitude Max: 52.0969
# Longitude Min: -93.4268
# Longitude Max: -18.5677

# %%
import glob

All_GFW_Grid = pd.DataFrame()
for year in range(2012, 2013):

    yearby = glob.glob('Fishing_By_Vessel/' + str(year) + "\*.csv")

    li = []
    for yr in yearby:
        df = pd.read_csv(yr, index_col=None, header=0)
        li.append(df)
        
    GFW_Year = pd.concat(li, axis=0, ignore_index=True)
    All_GFW_Grid = pd.concat([All_GFW_Grid, GFW_Year])
    
All_GFW_Grid
# Out:
#                             date  lat_bin  lon_bin       mmsi  fishing_hours
# 0        2012-01-01 00:00:00 UTC     -461     -607  416755000       2.457917
# 1        2012-01-01 00:00:00 UTC     -461     -607  440548000       2.400417
# 2        2012-01-01 00:00:00 UTC     -460     -607  440548000       1.614444
# 3        2012-01-01 00:00:00 UTC     -460     -607  416032500      11.497083
# 4        2012-01-01 00:00:00 UTC     -459     -607  416842000      11.521944
# 5        2012-01-01 00:00:00 UTC     -459     -606  416046800       4.023194
# 6        2012-01-01 00:00:00 UTC     -458     -607  441303000       0.783194
# 7        2012-01-01 00:00:00 UTC     -458     -606  441303000       3.201528
# 8        2012-01-01 00:00:00 UTC     -458     -606  440502000       2.402361
# 9        2012-01-01 00:00:00 UTC     -457     -607  441412000       4.037917
# 10       2012-01-01 00:00:00 UTC     -455     -601  441495000       2.433056
# 11       2012-01-01 00:00:00 UTC     -454     -606  440818000       4.017361
# 12       2012-01-01 00:00:00 UTC       73     -313  431316000       0.015278
# 13       2012-01-01 00:00:00 UTC     -160    -1214  431182000       3.316667
# 14       2012-01-01 00:00:00 UTC     -158    -1214  431182000       0.875139
# 15       2012-01-01 00:00:00 UTC     -157    -1214  431182000       0.116389
# 16       2012-01-01 00:00:00 UTC     -154    -1214  431182000       3.127778
# 17       2012-01-01 00:00:00 UTC     -153    -1215  431182000       6.638611
# 18       2012-01-01 00:00:00 UTC      -43    -1740  440108000       0.960833
# 19       2012-01-01 00:00:00 UTC      -42    -1740  440108000       1.780556
# 20       2012-01-01 00:00:00 UTC      -41     1785  538060017      12.167917
# 21       2012-01-01 00:00:00 UTC      -40    -1601  440617000       0.840000
# 22       2012-01-01 00:00:00 UTC      -40    -1600  440617000       1.049444
# 23       2012-01-01 00:00:00 UTC      -39     1786  538060017       4.797361
# 24       2012-01-01 00:00:00 UTC      -32     1627  440886000       6.675972
# 25       2012-01-01 00:00:00 UTC      -32     1630  440886000      12.198333
# 26       2012-01-01 00:00:00 UTC      -31     1626  440886000       2.654583
# 27       2012-01-01 00:00:00 UTC      -29     1626  440886000       4.553889
# 28       2012-01-01 00:00:00 UTC      -14     1780  440772000       4.969028
# 29       2012-01-01 00:00:00 UTC      -11     1783  440772000      10.569444
# ...                          ...      ...      ...        ...            ...
# 2139232  2012-12-31 00:00:00 UTC     -258      612  224049460       0.766667
# 2139233  2012-12-31 00:00:00 UTC     -258      611  224049460       0.638333
# 2139234  2012-12-31 00:00:00 UTC     -258      613  224049460       0.792917
# 2139235  2012-12-31 00:00:00 UTC     -258      360  432463000       2.496250
# 2139236  2012-12-31 00:00:00 UTC       -2     1739  441062000       1.569444
# 2139237  2012-12-31 00:00:00 UTC       -2     1741  441062000       0.725000
# 2139238  2012-12-31 00:00:00 UTC      255     -186  204232000       1.299722
# 2139239  2012-12-31 00:00:00 UTC      255     -187  204232000       0.448889
# 2139240  2012-12-31 00:00:00 UTC      255     -197  204232000       0.913750
# 2139241  2012-12-31 00:00:00 UTC      255     -196  204232000       0.893056
# 2139242  2012-12-31 00:00:00 UTC      255     1740  431725000       2.587917
# 2139243  2012-12-31 00:00:00 UTC      255     1742  431798000       1.992778
# 2139244  2012-12-31 00:00:00 UTC      511     1561  273896000       1.569306
# 2139245  2012-12-31 00:00:00 UTC      511      -95  228004700       1.303056
# 2139246  2012-12-31 00:00:00 UTC      511      -93  228004700       0.420278
# 2139247  2012-12-31 00:00:00 UTC      511      -94  228004700       2.203194
# 2139248  2012-12-31 00:00:00 UTC      511      -96  228004700       3.017083
# 2139249  2012-12-31 00:00:00 UTC      511     -115  224273000       4.040556
# 2139250  2012-12-31 00:00:00 UTC      511     -102  228020900       6.591111
# 2139251  2012-12-31 00:00:00 UTC      511     -103  228020900       6.314306
# 2139252  2012-12-31 00:00:00 UTC      511     -101  228020900       0.669444
# 2139253  2012-12-31 00:00:00 UTC      511     1560  273359300       1.427361
# 2139254  2012-12-31 00:00:00 UTC     -257      356  432426000       0.950000
# 2139255  2012-12-31 00:00:00 UTC     -257      630  225374000       0.621389
# 2139256  2012-12-31 00:00:00 UTC     -257     -109  224084640       5.734028
# 2139257  2012-12-31 00:00:00 UTC     -257     -110  224084640       1.658333
# 2139258  2012-12-31 00:00:00 UTC       -1     1739  441062000       1.773611
# 2139259  2012-12-31 00:00:00 UTC       -1     1740  441062000       1.821111
# 2139260  2012-12-31 00:00:00 UTC       -1     1741  441062000       0.986250
# 2139261  2012-12-31 00:00:00 UTC       -1     1450  432685000      12.329722
#
# [2139262 rows x 5 columns]

# %%
max(All_GFW_Grid.date)
# Out:
# '2012-12-31 00:00:00 UTC'

# %%
print("Latitude Min:", All_GFW_Grid.lat_bin.min())
print("Latitude Max:", All_GFW_Grid.lat_bin.max())

print("Longitude Min:", All_GFW_Grid.lon_bin.min())
print("Longitude Max:", All_GFW_Grid.lon_bin.max())
# Out:
# Latitude Min: -777
# Latitude Max: 910
# Longitude Min: -1800
# Longitude Max: 1810

# %% [markdown]
# ### Data Attr

# %%
# import pickle
# pickle_out = open("frame12.pickle","wb")
# pickle.dump(frame12,pickle_out)
# pickle_out.close()
